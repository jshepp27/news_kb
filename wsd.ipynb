# %%
from pprint import pprint
import json

triples = [json.loads(_)["openie"] for _ in open("data/processed/OIE_objects.jsonl")]

triples = [_[0] for _ in triples if len(_) > 0]
triples = triples[0:20]

# %%
# Clean, leammatise?
# Noun Phrase
# Word Sense, WordNet
# Paraphrase, PPDB
# Entity Linking
# IDF Token Overlap

ent1_list = list(set([_["subject"] for _ in triples]))
ent2_list = list(set([_["object"] for _ in triples]))

ent_list = list(set().union(ent1_list, ent2_list))
ent_list
# Out:
# ['Bitcoin ATMs',
#  'crypto law',
#  'Lee Jung Hoon',
#  'Ripple CEO Brad Garlinghouse',
#  'alleged grift',
#  'their role',
#  'Bahamas Liquidators',
#  'Track Stolen User Cash',
#  'Lightning Network',
#  'Car',
#  'after U.S. jobs report',
#  '$ 17K as Interest Rates Plunge',
#  'US Feds',
#  'cautious optimism',
#  'Crypto Conglomerate DCG',
#  'stablecoins',
#  'New Tokens',
#  'NFT Collective PROOF Signs',
#  'DOJ',
#  'FTX',
#  'Audi Backed Startup Holoride',
#  'Zero Hash',
#  'Equities',
#  'Congress May Restrict Stock Trading',
#  'growth',
#  'Morocco',
#  'First Instance',
#  'Crypto Bank Juno',
#  'Next Session',
#  'United Talent Agency',
#  'definition',
#  '2022',
#  'Bitcoin',
#  'Chains',
#  'Polygon Paid Top Solana Projects Y00ts 3M',
#  'Hong Kong Brokers',
#  'Virtual Asset Trading Law']

# %%
import string
import re

def clean_message(message):
    # Be Careful of Spaces
    cleaned = message

    cleaned = cleaned.lower()

    # Specific Symbols: ampersand, greater-than, less-than
    cleaned = re.sub(r"&amp", "and", cleaned)

    # Punctuation
    cleaned = re.sub(r"\b\s’s\s\b", " ", cleaned)
    cleaned = cleaned.translate(str.maketrans('', '', string.punctuation))

    # Remove URLs
    cleaned = re.sub(r"http\S+", "", cleaned)

    # Remove Symbols (Bullets, Punctuations, != Alphanumeric)
    cleaned = re.sub(r'[^\w]', ' ', cleaned)
    cleaned = re.sub("<[^>]*>", "", cleaned)
    cleaned = re.sub('[*”".?!,:;•/&+]', ' ', cleaned)
    cleaned = re.sub("([\(\[]).*?([\)\]])", "", cleaned)
    cleaned = re.sub(r'--'," ", cleaned)

    # ?
    cleaned = re.sub(r'(?<=[.,])(?=[^\s])', r' ', cleaned)
    cleaned = re.sub(r"@[^A-Za-z0-9*]+", "", cleaned)
    cleaned = re.sub(' +', ' ', cleaned)
    cleaned = re.sub(r'(\d+),(\d+),?(\d*)', " ", cleaned)

    # Clean spaces
    cleaned = " ".join(cleaned.split())

    return cleaned

ent_map = {}
for id, ent in enumerate(ent_list):
    ent_map[id] = {}
    ent_map[id]["text"] = clean_message(ent)
    ent_map[id]["wn_mask"] = [0] * len(ent_map[id]["text"].split())
    #ent_map[id]["noun_chunks"] = []

ent_map
# Out:
# {0: {'text': 'bitcoin atms', 'wn_mask': [0, 0]},
#  1: {'text': 'crypto law', 'wn_mask': [0, 0]},
#  2: {'text': 'lee jung hoon', 'wn_mask': [0, 0, 0]},
#  3: {'text': 'ripple ceo brad garlinghouse', 'wn_mask': [0, 0, 0, 0]},
#  4: {'text': 'alleged grift', 'wn_mask': [0, 0]},
#  5: {'text': 'their role', 'wn_mask': [0, 0]},
#  6: {'text': 'bahamas liquidators', 'wn_mask': [0, 0]},
#  7: {'text': 'track stolen user cash', 'wn_mask': [0, 0, 0, 0]},
#  8: {'text': 'lightning network', 'wn_mask': [0, 0]},
#  9: {'text': 'car', 'wn_mask': [0]},
#  10: {'text': 'after us jobs report', 'wn_mask': [0, 0, 0, 0]},
#  11: {'text': '17k as interest rates plunge', 'wn_mask': [0, 0, 0, 0, 0]},
#  12: {'text': 'us feds', 'wn_mask': [0, 0]},
#  13: {'text': 'cautious optimism', 'wn_mask': [0, 0]},
#  14: {'text': 'crypto conglomerate dcg', 'wn_mask': [0, 0, 0]},
#  15: {'text': 'stablecoins', 'wn_mask': [0]},
#  16: {'text': 'new tokens', 'wn_mask': [0, 0]},
#  17: {'text': 'nft collective proof signs', 'wn_mask': [0, 0, 0, 0]},
#  18: {'text': 'doj', 'wn_mask': [0]},
#  19: {'text': 'ftx', 'wn_mask': [0]},
#  20: {'text': 'audi backed startup holoride', 'wn_mask': [0, 0, 0, 0]},
#  21: {'text': 'zero hash', 'wn_mask': [0, 0]},
#  22: {'text': 'equities', 'wn_mask': [0]},
#  23: {'text': 'congress may restrict stock trading',
#   'wn_mask': [0, 0, 0, 0, 0]},
#  24: {'text': 'growth', 'wn_mask': [0]},
#  25: {'text': 'morocco', 'wn_mask': [0]},
#  26: {'text': 'first instance', 'wn_mask': [0, 0]},
#  27: {'text': 'crypto bank juno', 'wn_mask': [0, 0, 0]},
#  28: {'text': 'next session', 'wn_mask': [0, 0]},
#  29: {'text': 'united talent agency', 'wn_mask': [0, 0, 0]},
#  30: {'text': 'definition', 'wn_mask': [0]},
#  31: {'text': '2022', 'wn_mask': [0]},
#  32: {'text': 'bitcoin', 'wn_mask': [0]},
#  33: {'text': 'chains', 'wn_mask': [0]},
#  34: {'text': 'polygon paid top solana projects y00ts 3m',
#   'wn_mask': [0, 0, 0, 0, 0, 0, 0]},
#  35: {'text': 'hong kong brokers', 'wn_mask': [0, 0, 0]},
#  36: {'text': 'virtual asset trading law', 'wn_mask': [0, 0, 0, 0]}}

# %%
import random
from nltk.wsd import lesk

for _ in ent_map:
    sent = ent_map[_]["text"]
    tokens = sent.split()

    for tok in range(0, len(tokens)):
        res = lesk(sent, tokens[tok])

        # TODO: Make '98' Robust to change
        if len(dir(res)) == 98:
            ent_map[_]["wn_mask"][tok] = res.lemma_names()[0]

# %%
ent_map
# Out:
# {0: {'text': 'bitcoin atms', 'wn_mask': [0, 'standard_atmosphere']},
#  1: {'text': 'crypto law', 'wn_mask': [0, 'law']},
#  2: {'text': 'lee jung hoon', 'wn_mask': ['lee', 'Jung', 0]},
#  3: {'text': 'ripple ceo brad garlinghouse',
#   'wn_mask': ['ripple', 'chief_executive_officer', 'brad', 0]},
#  4: {'text': 'alleged grift', 'wn_mask': ['alleged', 0]},
#  5: {'text': 'their role', 'wn_mask': [0, 'role']},
#  6: {'text': 'bahamas liquidators', 'wn_mask': ['Bahamas', 'murderer']},
#  7: {'text': 'track stolen user cash',
#   'wn_mask': ['track', 'steal', 'user', 'cash']},
#  8: {'text': 'lightning network', 'wn_mask': ['lightning', 'network']},
#  9: {'text': 'car', 'wn_mask': ['car']},
#  10: {'text': 'after us jobs report',
#   'wn_mask': ['subsequently', 'uranium', 'speculate', 'reputation']},
#  11: {'text': '17k as interest rates plunge',
#   'wn_mask': [0, 'deoxyadenosine_monophosphate', 'sake', 'rates', 'plunge']},
#  12: {'text': 'us feds', 'wn_mask': ['uranium', 'Federal_Reserve_System']},
#  13: {'text': 'cautious optimism', 'wn_mask': ['timid', 'optimism']},
#  14: {'text': 'crypto conglomerate dcg', 'wn_mask': [0, 'pudding_stone', 0]},
#  15: {'text': 'stablecoins', 'wn_mask': [0]},
#  16: {'text': 'new tokens', 'wn_mask': ['raw', 'token']},
#  17: {'text': 'nft collective proof signs',
#   'wn_mask': [0, 'corporate', 'validation', 'signboard']},
#  18: {'text': 'doj', 'wn_mask': ['Department_of_Justice']},
#  19: {'text': 'ftx', 'wn_mask': [0]},
#  20: {'text': 'audi backed startup holoride',
#   'wn_mask': [0, 'bet_on', 'inauguration', 0]},
#  21: {'text': 'zero hash', 'wn_mask': ['zero', 'hashish']},
#  22: {'text': 'equities', 'wn_mask': ['fairness']},
#  23: {'text': 'congress may restrict stock trading',
#   'wn_mask': ['sexual_intercourse',
#    'whitethorn',
#    'restrict',
#    'store',
#    'trade']},
#  24: {'text': 'growth', 'wn_mask': ['increase']},
#  25: {'text': 'morocco', 'wn_mask': ['morocco']},
#  26: {'text': 'first instance', 'wn_mask': ['first_gear', 'example']},
#  27: {'text': 'crypto bank juno', 'wn_mask': [0, 'savings_bank', 'Juno']},
#  28: {'text': 'next session', 'wn_mask': ['next', 'session']},
#  29: {'text': 'united talent agency',
#   'wn_mask': ['united', 'talent', 'means']},
#  30: {'text': 'definition', 'wn_mask': ['definition']},
#  31: {'text': '2022', 'wn_mask': [0]},
#  32: {'text': 'bitcoin', 'wn_mask': [0]},
#  33: {'text': 'chains', 'wn_mask': ['range']},
#  34: {'text': 'polygon paid top solana projects y00ts 3m',
#   'wn_mask': ['polygon', 'pay_up', 'top', 0, 'project', 0, 0]},
#  35: {'text': 'hong kong brokers', 'wn_mask': [0, 0, 'broker']},
#  36: {'text': 'virtual asset trading law',
#   'wn_mask': ['virtual', 'asset', 'trade', 'law']}}

# %%
# Entity Link
# Stanza Pipeline
import stanza
nlp = stanza.Pipeline(lang="en", processors="tokenize, mwt, pos, ner")
# Out:
# 2023-01-12 13:31:11 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# 2023-01-12 13:31:12 WARNING: Can not find mwt: default from official model list. Ignoring it.
# 2023-01-12 13:31:12 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | combined  |
# | pos       | combined  |
# | ner       | ontonotes |
# =========================
#
# 2023-01-12 13:31:12 INFO: Use device: cpu
# 2023-01-12 13:31:12 INFO: Loading: tokenize
# 2023-01-12 13:31:12 INFO: Loading: pos
# 2023-01-12 13:31:13 INFO: Loading: ner
# 2023-01-12 13:31:13 INFO: Done loading processors!

# %%
for _ in range(0, len(ent_map) - 1):
    sent = ent_map[_]["text"]
    ent_map[_]["ner_mask"] = [0] * len(sent.split())

    doc = nlp(sent)

    for id, sent in enumerate(doc.sentences):
        for ent in sent.ents:
            ent_map[_]["ner_mask"][id] = (ent.text, ent.type)

# %%
ent_map
# Out:
# {0: {'text': 'bitcoin atms',
#   'wn_mask': [0, 'standard_atmosphere'],
#   'ner_mask': [0, 0]},
#  1: {'text': 'crypto law', 'wn_mask': [0, 'law'], 'ner_mask': [0, 0]},
#  2: {'text': 'lee jung hoon',
#   'wn_mask': ['lee', 'Jung', 0],
#   'ner_mask': [0, 0, 0]},
#  3: {'text': 'ripple ceo brad garlinghouse',
#   'wn_mask': ['ripple', 'chief_executive_officer', 'brad', 0],
#   'ner_mask': [0, 0, 0, 0]},
#  4: {'text': 'alleged grift', 'wn_mask': ['alleged', 0], 'ner_mask': [0, 0]},
#  5: {'text': 'their role', 'wn_mask': [0, 'role'], 'ner_mask': [0, 0]},
#  6: {'text': 'bahamas liquidators',
#   'wn_mask': ['Bahamas', 'murderer'],
#   'ner_mask': [0, 0]},
#  7: {'text': 'track stolen user cash',
#   'wn_mask': ['track', 'steal', 'user', 'cash'],
#   'ner_mask': [0, 0, 0, 0]},
#  8: {'text': 'lightning network',
#   'wn_mask': ['lightning', 'network'],
#   'ner_mask': [0, 0]},
#  9: {'text': 'car', 'wn_mask': ['car'], 'ner_mask': [0]},
#  10: {'text': 'after us jobs report',
#   'wn_mask': ['subsequently', 'uranium', 'speculate', 'reputation'],
#   'ner_mask': [0, 0, 0, 0]},
#  11: {'text': '17k as interest rates plunge',
#   'wn_mask': [0, 'deoxyadenosine_monophosphate', 'sake', 'rates', 'plunge'],
#   'ner_mask': [('17', 'CARDINAL'), 0, 0, 0, 0]},
#  12: {'text': 'us feds',
#   'wn_mask': ['uranium', 'Federal_Reserve_System'],
#   'ner_mask': [0, 0]},
#  13: {'text': 'cautious optimism',
#   'wn_mask': ['timid', 'optimism'],
#   'ner_mask': [0, 0]},
#  14: {'text': 'crypto conglomerate dcg',
#   'wn_mask': [0, 'pudding_stone', 0],
#   'ner_mask': [0, 0, 0]},
#  15: {'text': 'stablecoins', 'wn_mask': [0], 'ner_mask': [0]},
#  16: {'text': 'new tokens', 'wn_mask': ['raw', 'token'], 'ner_mask': [0, 0]},
#  17: {'text': 'nft collective proof signs',
#   'wn_mask': [0, 'corporate', 'validation', 'signboard'],
#   'ner_mask': [0, 0, 0, 0]},
#  18: {'text': 'doj', 'wn_mask': ['Department_of_Justice'], 'ner_mask': [0]},
#  19: {'text': 'ftx', 'wn_mask': [0], 'ner_mask': [0]},
#  20: {'text': 'audi backed startup holoride',
#   'wn_mask': [0, 'bet_on', 'inauguration', 0],
#   'ner_mask': [0, 0, 0, 0]},
#  21: {'text': 'zero hash',
#   'wn_mask': ['zero', 'hashish'],
#   'ner_mask': [('zero', 'CARDINAL'), 0]},
#  22: {'text': 'equities', 'wn_mask': ['fairness'], 'ner_mask': [0]},
#  23: {'text': 'congress may restrict stock trading',
#   'wn_mask': ['sexual_intercourse',
#    'whitethorn',
#    'restrict',
#    'store',
#    'trade'],
#   'ner_mask': [0, 0, 0, 0, 0]},
#  24: {'text': 'growth', 'wn_mask': ['increase'], 'ner_mask': [0]},
#  25: {'text': 'morocco', 'wn_mask': ['morocco'], 'ner_mask': [0]},
#  26: {'text': 'first instance',
#   'wn_mask': ['first_gear', 'example'],
#   'ner_mask': [('first', 'ORDINAL'), 0]},
#  27: {'text': 'crypto bank juno',
#   'wn_mask': [0, 'savings_bank', 'Juno'],
#   'ner_mask': [0, 0, 0]},
#  28: {'text': 'next session',
#   'wn_mask': ['next', 'session'],
#   'ner_mask': [0, 0]},
#  29: {'text': 'united talent agency',
#   'wn_mask': ['united', 'talent', 'means'],
#   'ner_mask': [0, 0, 0]},
#  30: {'text': 'definition', 'wn_mask': ['definition'], 'ner_mask': [0]},
#  31: {'text': '2022', 'wn_mask': [0], 'ner_mask': [0]},
#  32: {'text': 'bitcoin', 'wn_mask': [0], 'ner_mask': [0]},
#  33: {'text': 'chains', 'wn_mask': ['range'], 'ner_mask': [0]},
#  34: {'text': 'polygon paid top solana projects y00ts 3m',
#   'wn_mask': ['polygon', 'pay_up', 'top', 0, 'project', 0, 0],
#   'ner_mask': [('3m', 'QUANTITY'), 0, 0, 0, 0, 0, 0]},
#  35: {'text': 'hong kong brokers',
#   'wn_mask': [0, 0, 'broker'],
#   'ner_mask': [0, 0, 0]},
#  36: {'text': 'virtual asset trading law',
#   'wn_mask': ['virtual', 'asset', 'trade', 'law']}}

# %%
# Spotlight
import requests
from IPython.core.display import display, HTML

spotlight_url = "http://api.dbpedia-spotlight.org/en/annotate"

headers = {
    "accept": "application/json"
}

NEL = {}

for _ in range(0, len(ent_map)):
    NEL[_] = {}

    params = {
        "text": ent_map[_]["text"],
        "confidence": 0.25
    }
    try:
        res = requests.get(spotlight_url, params=params, headers=headers)
        NEL[_]["spotlight"] = res.json()

    except:
        NEL[_]["spotlight"] = "NIL"
        continue
# Out:
# /var/folders/9y/jc1z3n7n78ndcq81djws05m00000gn/T/ipykernel_26770/3718723631.py:3: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
pprint(NEL)
# Out:
# {0: {'spotlight': {'@confidence': '0.25',
#                    '@policy': 'whitelist',
#                    '@sparql': '',
#                    '@support': '0',
#                    '@text': 'bitcoin atms',
#                    '@types': '',
#                    'Resources': [{'@URI': 'http://dbpedia.org/resource/Bitcoin_ATM',
#                                   '@offset': '0',
#                                   '@percentageOfSecondRank': '0.0',
#                                   '@similarityScore': '0.9999999999999964',
#                                   '@support': '17',
#                                   '@surfaceForm': 'bitcoin atms',
#                                   '@types': ''}]}},
#  1: {'spotlight': {'@confidence': '0.25',
#                    '@policy': 'whitelist',
#                    '@sparql': '',
#                    '@support': '0',
#                    '@text': 'crypto law',
#                    '@types': '',
#                    'Resources': [{'@URI': 'http://dbpedia.org/resource/Cryptography',
#                                   '@offset': '0',
#                                   '@percentageOfSecondRank': '0.5383956435718668',
#                                   '@similarityScore': '0.6500272582959418',
#                                   '@support': '4195',
#                                   '@surfaceForm': 'crypto',
#                                   '@types': ''},
#                                  {'@URI': 'http://dbpedia.org/resource/Law',
#                                   '@offset': '7',
#                                   '@percentageOfSecondRank': '0.008857866112017488',
#                                   '@similarityScore': '0.9894480017592768',
#                                   '@support': '28065',
#                                   '@surfaceForm': 'law',
#                                   '@types': ''}]}},
#  2: {'spotlight': {'@confidence': '0.25',
#                    '@policy': 'whitelist',
#                    '@sparql': '',
#                    '@support': '0',
#                    '@text': 'lee jung hoon',
#                    '@types': '',
#                    'Resources': [{'@URI': 'http://dbpedia.org/resource/Lee_Jung',
#                                   '@offset': '0',
#                                   '@percentageOfSecondRank': '0.0',
#                                   '@similarityScore': '0.9999999999380123',
#                                   '@support': '20',
#                                   '@surfaceForm': 'lee jung',
#                                   '@types': 'Http://xmlns.com/foaf/0.1/Person,Wikidata:Q5,Wikidata:Q483501,Wikidata:Q24229398,Wikidata:Q215627,DUL:NaturalPerson,DUL:Agent,Schema:Person,Schema:MusicGroup,DBpedia:Person,DBpedia:Artist,DBpedia:Agent,DBpedia:MusicalArtist'},
#                                  {'@URI': 'http://dbpedia.org/resource/Jung_Hoon',
#                                   '@offset': '4',
#                                   '@percentageOfSecondRank': '0.0',
#                                   '@similarityScore': '0.999997847105534',
#                                   '@support': '4',
#                                   '@surfaceForm': 'jung hoon',
#                                   '@types': 'Http://xmlns.com/foaf/0.1/Person,Wikidata:Q937857,Wikidata:Q5,Wikidata:Q24229398,Wikidata:Q215627,DUL:NaturalPerson,DUL:Agent,Schema:Person,DBpedia:Person,DBpedia:Athlete,DBpedia:Agent,DBpedia:SoccerPlayer'}]}},
#  3: {'spotlight': {'@confidence': '0.25',
#                    '@policy': 'whitelist',
#                    '@sparql': '',
#                    '@support': '0',
#                    '@text': 'ripple ceo brad garlinghouse',
#                    '@types': '',
#                    'Resources': [{'@URI': 'http://dbpedia.org/resource/Ripple_marks',
#                                   '@offset': '0',
#                                   '@percentageOfSecondRank': '0.6899198224818427',
#                                   '@similarityScore': '0.5747704647545796',
#                                   '@support': '138',
#                                   '@surfaceForm': 'ripple',
#                                   '@types': ''},
#                                  {'@URI': 'http://dbpedia.org/resource/Chief_executive_officer',
#                                   '@offset': '7',
#                                   '@percentageOfSecondRank': '1.907178482358419E-5',
#                                   '@similarityScore': '0.9999793391801908',
#                                   '@support': '21733',
#                                   '@surfaceForm': 'ceo',
#                                   '@types': ''},
#                                  {'@URI': 'http://dbpedia.org/resource/Brad_Garlinghouse',
#                                   '@offset': '11',
#                                   '@percentageOfSecondRank': '0.0',
#                                   '@similarityScore': '1.0',
#                                   '@support': '7',
#                                   '@surfaceForm': 'brad garlinghouse',
#                                   '@types': 'Http://xmlns.com/foaf/0.1/Person,Wikidata:Q5,Wikidata:Q24229398,Wikidata:Q215627,DUL:NaturalPerson,DUL:Agent,Schema:Person,DBpedia:Agent,DBpedia:Person'}]}},
#  4: {'spotlight': {'@confidence': '0.25',
#                    '@policy': 'whitelist',
#                    '@sparql': '',
#                    '@support': '0',
#                    '@text': 'alleged grift',
#                    '@types': '',
#                    'Resources': [{'@URI': 'http://dbpedia.org/resource/Allegation',
#                                   '@offset': '0',
#                                   '@percentageOfSecondRank': '0.0',
#                                   '@similarityScore': '0.9999547964592425',
#                                   '@support': '360',
#                                   '@surfaceForm': 'alleged',
#                                   '@types': ''},
#                                  {'@URI': 'http://dbpedia.org/resource/Confidence_trick',
#                                   '@offset': '8',
#                                   '@percentageOfSecondRank': '0.0',
#                                   '@similarityScore': '0.9999998400953615',
#                                   '@support': '2370',
#                                   '@surfaceForm': 'grift',
#                                   '@types': ''}]}},
#  5: {'spotlight': {'@confidence': '0.25',
#                    '@policy': 'whitelist',
#                    '@sparql': '',
#                    '@support': '0',
#                    '@text': 'their role',
#                    '@types': ''}},
#  6: {'spotlight': {'@confidence': '0.25',
#                    '@policy': 'whitelist',
#                    '@sparql': '',
#                    '@support': '0',
#                    '@text': 'bahamas liquidators',
#                    '@types': '',
#                    'Resources': [{'@URI': 'http://dbpedia.org/resource/The_Bahamas',
#                                   '@offset': '0',
#                                   '@percentageOfSecondRank': '8.125255637401517E-4',
#                                   '@similarityScore': '0.9991237623844647',
#                                   '@support': '10647',
#                                   '@surfaceForm': 'bahamas',
#                                   '@types': 'Wikidata:Q6256,Schema:Place,Schema:Country,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Country'},
#                                  {'@URI': 'http://dbpedia.org/resource/Liquidation',
#                                   '@offset': '8',
#                                   '@percentageOfSecondRank': '0.7540913006887108',
#                                   '@similarityScore': '0.5488692236753642',
#                                   '@support': '1623',
#                                   '@surfaceForm': 'liquidators',
#                                   '@types': ''}]}},
#  7: {'spotlight': {'@confidence': '0.25',
#                    '@policy': 'whitelist',
#                    '@sparql': '',
#                    '@support': '0',
#                    '@text': 'track stolen user cash',
#                    '@types': '',
#                    'Resources': [{'@URI': 'http://dbpedia.org/resource/Track_and_field',
#                                   '@offset': '0',
#                                   '@percentageOfSecondRank': '0.05900918823606609',
#                                   '@similarityScore': '0.896046136215872',
#                                   '@support': '19720',
#                                   '@surfaceForm': 'track',
#                                   '@types': 'Wikidata:Q349,Wikidata:Q1914636,Http://www.ontologydesignpatterns.org/ont/d0.owl#Activity,DBpedia:Activity,DBpedia:Sport'},
#                                  {'@URI': 'http://dbpedia.org/resource/Stolen_base',
#                                   '@offset': '6',
#                                   '@percentageOfSecondRank': '0.7976124265889077',
#                                   '@similarityScore': '0.4725443650061586',
#                                   '@support': '3328',
#                                   '@surfaceForm': 'stolen',
#                                   '@types': ''},
#                                  {'@URI': 'http://dbpedia.org/resource/Wikipedia',
#                                   '@offset': '13',
#                                   '@percentageOfSecondRank': '0.16026742716696143',
#                                   '@similarityScore': '0.6743410545256104',
#                                   '@support': '107729',
#                                   '@surfaceForm': 'user',
#                                   '@types': 'Wikidata:Q386724,Schema:WebSite,Schema:CreativeWork,DBpedia:Work,DBpedia:Website'},
#                                  {'@URI': 'http://dbpedia.org/resource/Cash',
#                                   '@offset': '18',
#                                   '@percentageOfSecondRank': '0.00620871975551661',
#                                   '@similarityScore': '0.9913026427205467',
#                                   '@support': '1318',
#                                   '@surfaceForm': 'cash',
#                                   '@types': ''}]}},
#  8: {'spotlight': {'@confidence': '0.25',
#                    '@policy': 'whitelist',
#                    '@sparql': '',
#                    '@support': '0',
#                    '@text': 'lightning network',
#                    '@types': '',
#                    'Resources': [{'@URI': 'http://dbpedia.org/resource/Lightning',
#                                   '@offset': '0',
#                                   '@percentageOfSecondRank': '2.225762415248535E-5',
#                                   '@similarityScore': '0.9999772786296658',
#                                   '@support': '4159',
#                                   '@surfaceForm': 'lightning',
#                                   '@types': ''},
#                                  {'@URI': 'http://dbpedia.org/resource/Computer_network',
#                                   '@offset': '10',
#                                   '@percentageOfSecondRank': '0.26735963559863174',
#                                   '@similarityScore': '0.7171366190701741',
#                                   '@support': '5163',
#                                   '@surfaceForm': 'network',
#                                   '@types': ''}]}},
#  9: {'spotlight': {'@confidence': '0.25',
#                    '@policy': 'whitelist',
#                    '@sparql': '',
#                    '@support': '0',
#                    '@text': 'car',
#                    '@types': '',
#                    'Resources': [{'@URI': 'http://dbpedia.org/resource/Car',
#                                   '@offset': '0',
#                                   '@percentageOfSecondRank': '0.001189184761495237',
#                                   '@similarityScore': '0.9971300274427468',
#                                   '@support': '11951',
#                                   '@surfaceForm': 'car',
#                                   '@types': ''}]}},
#  10: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'after us jobs report',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Employment',
#                                    '@offset': '9',
#                                    '@percentageOfSecondRank': '0.2767780733123252',
#                                    '@similarityScore': '0.7474027159204348',
#                                    '@support': '7438',
#                                    '@surfaceForm': 'jobs',
#                                    '@types': ''}]}},
#  11: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': '17k as interest rates plunge',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Interest_rate',
#                                    '@offset': '7',
#                                    '@percentageOfSecondRank': '0.005693170408786441',
#                                    '@similarityScore': '0.99134509109772',
#                                    '@support': '2545',
#                                    '@surfaceForm': 'interest rates',
#                                    '@types': ''},
#                                   {'@URI': 'http://dbpedia.org/resource/Waterfall',
#                                    '@offset': '22',
#                                    '@percentageOfSecondRank': '0.14690580432743616',
#                                    '@similarityScore': '0.8719090808010418',
#                                    '@support': '4537',
#                                    '@surfaceForm': 'plunge',
#                                    '@types': ''}]}},
#  12: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'us feds',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Feds',
#                                    '@offset': '3',
#                                    '@percentageOfSecondRank': '0.19797898832934624',
#                                    '@similarityScore': '0.821337471679095',
#                                    '@support': '24',
#                                    '@surfaceForm': 'feds',
#                                    '@types': ''}]}},
#  13: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'cautious optimism',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Optimism',
#                                    '@offset': '9',
#                                    '@percentageOfSecondRank': '4.260364542713213E-5',
#                                    '@similarityScore': '0.9999413981996117',
#                                    '@support': '451',
#                                    '@surfaceForm': 'optimism',
#                                    '@types': ''}]}},
#  14: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'crypto conglomerate dcg',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Cryptography',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '0.5095760385190955',
#                                    '@similarityScore': '0.662436926928639',
#                                    '@support': '4195',
#                                    '@surfaceForm': 'crypto',
#                                    '@types': ''},
#                                   {'@URI': 'http://dbpedia.org/resource/Conglomerate_(geology)',
#                                    '@offset': '7',
#                                    '@percentageOfSecondRank': '0.8892777140055068',
#                                    '@similarityScore': '0.32758444417596105',
#                                    '@support': '1693',
#                                    '@surfaceForm': 'conglomerate',
#                                    '@types': ''}]}},
#  15: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'stablecoins',
#                     '@types': ''}},
#  16: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'new tokens',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Token_coin',
#                                    '@offset': '4',
#                                    '@percentageOfSecondRank': '0.15821923229700713',
#                                    '@similarityScore': '0.78053749508002',
#                                    '@support': '397',
#                                    '@surfaceForm': 'tokens',
#                                    '@types': ''}]}},
#  17: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'nft collective proof signs',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Collective',
#                                    '@offset': '4',
#                                    '@percentageOfSecondRank': '0.0608349541415483',
#                                    '@similarityScore': '0.8878672767363622',
#                                    '@support': '760',
#                                    '@surfaceForm': 'collective',
#                                    '@types': ''},
#                                   {'@URI': 'http://dbpedia.org/resource/Mathematical_proof',
#                                    '@offset': '15',
#                                    '@percentageOfSecondRank': '0.08602384968497678',
#                                    '@similarityScore': '0.8602841413011482',
#                                    '@support': '1412',
#                                    '@surfaceForm': 'proof',
#                                    '@types': ''},
#                                   {'@URI': 'http://dbpedia.org/resource/Medical_sign',
#                                    '@offset': '21',
#                                    '@percentageOfSecondRank': '0.9000497654528875',
#                                    '@similarityScore': '0.37498909033960354',
#                                    '@support': '760',
#                                    '@surfaceForm': 'signs',
#                                    '@types': ''}]}},
#  18: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'doj',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/United_States_Department_of_Justice',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '1.819159083800472E-4',
#                                    '@similarityScore': '0.9998152389109537',
#                                    '@support': '8301',
#                                    '@surfaceForm': 'doj',
#                                    '@types': ''}]}},
#  19: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'ftx',
#                     '@types': ''}},
#  20: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'audi backed startup holoride',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Audi',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '0.009384282273356633',
#                                    '@similarityScore': '0.9821393665151872',
#                                    '@support': '7444',
#                                    '@surfaceForm': 'audi',
#                                    '@types': ''},
#                                   {'@URI': 'http://dbpedia.org/resource/A-side_and_B-side',
#                                    '@offset': '5',
#                                    '@percentageOfSecondRank': '0.3284349701780198',
#                                    '@similarityScore': '0.7527654789683169',
#                                    '@support': '11083',
#                                    '@surfaceForm': 'backed',
#                                    '@types': ''},
#                                   {'@URI': 'http://dbpedia.org/resource/Startup_company',
#                                    '@offset': '12',
#                                    '@percentageOfSecondRank': '6.806992244736246E-5',
#                                    '@similarityScore': '0.999931934704762',
#                                    '@support': '2088',
#                                    '@surfaceForm': 'startup',
#                                    '@types': ''}]}},
#  21: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'zero hash',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Hash_function',
#                                    '@offset': '5',
#                                    '@percentageOfSecondRank': '0.3081064077903182',
#                                    '@similarityScore': '0.6838329409641456',
#                                    '@support': '1109',
#                                    '@surfaceForm': 'hash',
#                                    '@types': ''}]}},
#  22: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'equities',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Stock',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '0.22652462335427703',
#                                    '@similarityScore': '0.8151263316384454',
#                                    '@support': '5580',
#                                    '@surfaceForm': 'equities',
#                                    '@types': ''}]}},
#  23: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'congress may restrict stock trading',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/United_States_Congress',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '0.2195951448543941',
#                                    '@similarityScore': '0.7729330253727196',
#                                    '@support': '30686',
#                                    '@surfaceForm': 'congress',
#                                    '@types': 'Wikidata:Q43229,Wikidata:Q24229398,Wikidata:Q11204,DUL:SocialPerson,DUL:Agent,Schema:Organization,DBpedia:Organisation,DBpedia:Agent,DBpedia:Legislature'},
#                                   {'@URI': 'http://dbpedia.org/resource/Restrict',
#                                    '@offset': '13',
#                                    '@percentageOfSecondRank': '0.03448524154962706',
#                                    '@similarityScore': '0.9663295763207704',
#                                    '@support': '24',
#                                    '@surfaceForm': 'restrict',
#                                    '@types': ''},
#                                   {'@URI': 'http://dbpedia.org/resource/Stock_trader',
#                                    '@offset': '22',
#                                    '@percentageOfSecondRank': '0.0',
#                                    '@similarityScore': '0.9999999998681872',
#                                    '@support': '287',
#                                    '@surfaceForm': 'stock trading',
#                                    '@types': ''}]}},
#  24: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'growth',
#                     '@types': ''}},
#  25: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'morocco',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Morocco_leather',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '0.0',
#                                    '@similarityScore': '0.9998802844867999',
#                                    '@support': '57',
#                                    '@surfaceForm': 'morocco',
#                                    '@types': ''}]}},
#  26: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'first instance',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Instance_variable',
#                                    '@offset': '6',
#                                    '@percentageOfSecondRank': '0.6578026258134628',
#                                    '@similarityScore': '0.4115536670499461',
#                                    '@support': '46',
#                                    '@surfaceForm': 'instance',
#                                    '@types': ''}]}},
#  27: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'crypto bank juno',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Cryptocurrency',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '0.8743204226182699',
#                                    '@similarityScore': '0.5335263581257452',
#                                    '@support': '1278',
#                                    '@surfaceForm': 'crypto',
#                                    '@types': ''},
#                                   {'@URI': 'http://dbpedia.org/resource/Juno_Award',
#                                    '@offset': '12',
#                                    '@percentageOfSecondRank': '0.03559922436303785',
#                                    '@similarityScore': '0.9571558902184347',
#                                    '@support': '3015',
#                                    '@surfaceForm': 'juno',
#                                    '@types': 'Wikidata:Q618779,DBpedia:Award'}]}},
#  28: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'next session',
#                     '@types': ''}},
#  29: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'united talent agency',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/United_Talent_Agency',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '0.0',
#                                    '@similarityScore': '0.999999999999936',
#                                    '@support': '142',
#                                    '@surfaceForm': 'united talent agency',
#                                    '@types': 'Wikidata:Q4830453,Wikidata:Q43229,Wikidata:Q24229398,DUL:SocialPerson,DUL:Agent,Schema:Organization,DBpedia:Organisation,DBpedia:Agent,DBpedia:Company'}]}},
#  30: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'definition',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Definition',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '0.00529559135987487',
#                                    '@similarityScore': '0.9874263934853256',
#                                    '@support': '997',
#                                    '@surfaceForm': 'definition',
#                                    '@types': ''}]}},
#  31: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': '2022',
#                     '@types': ''}},
#  32: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'bitcoin',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Bitcoin',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '0.0',
#                                    '@similarityScore': '0.9999999363898466',
#                                    '@support': '3013',
#                                    '@surfaceForm': 'bitcoin',
#                                    '@types': ''}]}},
#  33: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'chains',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Chain_store',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '0.5389830252161478',
#                                    '@similarityScore': '0.60314433370375',
#                                    '@support': '2052',
#                                    '@surfaceForm': 'chains',
#                                    '@types': ''}]}},
#  34: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'polygon paid top solana projects y00ts 3m',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Polygon',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '0.0012377424324129457',
#                                    '@similarityScore': '0.9974341007177843',
#                                    '@support': '2408',
#                                    '@surfaceForm': 'polygon',
#                                    '@types': ''},
#                                   {'@URI': 'http://dbpedia.org/resource/Jimmy_Wales',
#                                    '@offset': '13',
#                                    '@percentageOfSecondRank': '0.7266670449846948',
#                                    '@similarityScore': '0.5350188434899058',
#                                    '@support': '3075',
#                                    '@surfaceForm': 'top',
#                                    '@types': 'Http://xmlns.com/foaf/0.1/Person,Wikidata:Q5,Wikidata:Q24229398,Wikidata:Q215627,DUL:NaturalPerson,DUL:Agent,Schema:Person,DBpedia:Agent,DBpedia:Person'},
#                                   {'@URI': 'http://dbpedia.org/resource/Wikimedia_Foundation',
#                                    '@offset': '24',
#                                    '@percentageOfSecondRank': '0.20731345359050452',
#                                    '@similarityScore': '0.8199651743530524',
#                                    '@support': '5286',
#                                    '@surfaceForm': 'projects',
#                                    '@types': 'Wikidata:Q43229,Wikidata:Q24229398,DUL:SocialPerson,DUL:Agent,Schema:Organization,DBpedia:Agent,DBpedia:Organisation'},
#                                   {'@URI': 'http://dbpedia.org/resource/3M',
#                                    '@offset': '39',
#                                    '@percentageOfSecondRank': '1.092017748101893E-8',
#                                    '@similarityScore': '0.9999999794965648',
#                                    '@support': '1319',
#                                    '@surfaceForm': '3m',
#                                    '@types': 'Wikidata:Q4830453,Wikidata:Q43229,Wikidata:Q24229398,DUL:SocialPerson,DUL:Agent,Schema:Organization,DBpedia:Organisation,DBpedia:Agent,DBpedia:Company'}]}},
#  35: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'hong kong brokers',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Hong_Kong',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '0.0013134747902732522',
#                                    '@similarityScore': '0.996783991427079',
#                                    '@support': '78598',
#                                    '@surfaceForm': 'hong kong',
#                                    '@types': ''},
#                                   {'@URI': 'http://dbpedia.org/resource/Broker',
#                                    '@offset': '10',
#                                    '@percentageOfSecondRank': '0.02851695928687857',
#                                    '@similarityScore': '0.9289065125278434',
#                                    '@support': '1345',
#                                    '@surfaceForm': 'brokers',
#                                    '@types': ''}]}},
#  36: {'spotlight': {'@confidence': '0.25',
#                     '@policy': 'whitelist',
#                     '@sparql': '',
#                     '@support': '0',
#                     '@text': 'virtual asset trading law',
#                     '@types': '',
#                     'Resources': [{'@URI': 'http://dbpedia.org/resource/Virtual_channel',
#                                    '@offset': '0',
#                                    '@percentageOfSecondRank': '0.8009443855939395',
#                                    '@similarityScore': '0.5286220927737195',
#                                    '@support': '4551',
#                                    '@surfaceForm': 'virtual',
#                                    '@types': ''},
#                                   {'@URI': 'http://dbpedia.org/resource/Asset',
#                                    '@offset': '8',
#                                    '@percentageOfSecondRank': '6.550509750716871E-4',
#                                    '@similarityScore': '0.9989377852894122',
#                                    '@support': '3484',
#                                    '@surfaceForm': 'asset',
#                                    '@types': ''},
#                                   {'@URI': 'http://dbpedia.org/resource/Law',
#                                    '@offset': '22',
#                                    '@percentageOfSecondRank': '0.012703637451932795',
#                                    '@similarityScore': '0.9856256710106651',
#                                    '@support': '28065',
#                                    '@surfaceForm': 'law',
#                                    '@types': ''}]}}}

# %%
# TODO: Mask
# TODO: Advanced Meta Data

def locate(text, surface_form):
    items = text.split()
    len_ = len(surface_form.split())

    for idx, _ in enumerate(items):
        if len_ > 1:
            surface_form = surface_form.split()[0]

        if _.startswith(surface_form):
            return (idx, idx + len_)

        else: None

count = 0
for _ in range(0, len(ent_map)):
    count += 1

    if NEL[_]["spotlight"] == "NIL":
        continue

    else:

        link_text = ent_map[_]["text"].split()

        if "Resources" in NEL[_]["spotlight"]:
            for ent in NEL[_]["spotlight"]["Resources"]:
                surface_form = ent["@surfaceForm"]
                uri = ent["@URI"]

                try:
                    start, finish = locate(ent_map[_]["text"], surface_form)

                except:
                    continue

                if start != finish:
                    # Slice Assignment:
                    link_text[start: finish] = [f"[{surface_form}, {uri}]"]

                elif start == finish:
                    link_text[start] = f"[{surface_form}, {uri}]"

            disambiguated = " ".join(_ for _ in link_text)
            ent_map[_]["NEL_text"] = disambiguated
            print(ent_map[_]["text"])
            print(disambiguated, "\n")

        else: continue
# Out:
# bitcoin atms
# [bitcoin atms, http://dbpedia.org/resource/Bitcoin_ATM]
#
# crypto law
# [crypto, http://dbpedia.org/resource/Cryptography] [law, http://dbpedia.org/resource/Law]
#
# lee jung hoon
# [lee jung, http://dbpedia.org/resource/Lee_Jung] [jung hoon, http://dbpedia.org/resource/Jung_Hoon]
#
# ripple ceo brad garlinghouse
# [ripple, http://dbpedia.org/resource/Ripple_marks] [ceo, http://dbpedia.org/resource/Chief_executive_officer] [brad garlinghouse, http://dbpedia.org/resource/Brad_Garlinghouse]
#
# alleged grift
# [alleged, http://dbpedia.org/resource/Allegation] [grift, http://dbpedia.org/resource/Confidence_trick]
#
# bahamas liquidators
# [bahamas, http://dbpedia.org/resource/The_Bahamas] [liquidators, http://dbpedia.org/resource/Liquidation]
#
# track stolen user cash
# [track, http://dbpedia.org/resource/Track_and_field] [stolen, http://dbpedia.org/resource/Stolen_base] [user, http://dbpedia.org/resource/Wikipedia] [cash, http://dbpedia.org/resource/Cash]
#
# lightning network
# [lightning, http://dbpedia.org/resource/Lightning] [network, http://dbpedia.org/resource/Computer_network]
#
# car
# [car, http://dbpedia.org/resource/Car]
#
# after us jobs report
# after us [jobs, http://dbpedia.org/resource/Employment] report
#
# 17k as interest rates plunge
# 17k as [interest rates, http://dbpedia.org/resource/Interest_rate] plunge [plunge, http://dbpedia.org/resource/Waterfall]
#
# us feds
# us [feds, http://dbpedia.org/resource/Feds]
#
# cautious optimism
# cautious [optimism, http://dbpedia.org/resource/Optimism]
#
# crypto conglomerate dcg
# [crypto, http://dbpedia.org/resource/Cryptography] [conglomerate, http://dbpedia.org/resource/Conglomerate_(geology)] dcg
#
# new tokens
# new [tokens, http://dbpedia.org/resource/Token_coin]
#
# nft collective proof signs
# nft [collective, http://dbpedia.org/resource/Collective] [proof, http://dbpedia.org/resource/Mathematical_proof] [signs, http://dbpedia.org/resource/Medical_sign]
#
# doj
# [doj, http://dbpedia.org/resource/United_States_Department_of_Justice]
#
# audi backed startup holoride
# [audi, http://dbpedia.org/resource/Audi] [backed, http://dbpedia.org/resource/A-side_and_B-side] [startup, http://dbpedia.org/resource/Startup_company] holoride
#
# zero hash
# zero [hash, http://dbpedia.org/resource/Hash_function]
#
# equities
# [equities, http://dbpedia.org/resource/Stock]
#
# congress may restrict stock trading
# [congress, http://dbpedia.org/resource/United_States_Congress] may [restrict, http://dbpedia.org/resource/Restrict] [stock trading, http://dbpedia.org/resource/Stock_trader]
#
# morocco
# [morocco, http://dbpedia.org/resource/Morocco_leather]
#
# first instance
# first [instance, http://dbpedia.org/resource/Instance_variable]
#
# crypto bank juno
# [crypto, http://dbpedia.org/resource/Cryptocurrency] bank [juno, http://dbpedia.org/resource/Juno_Award]
#
# united talent agency
# [united talent agency, http://dbpedia.org/resource/United_Talent_Agency]
#
# definition
# [definition, http://dbpedia.org/resource/Definition]
#
# bitcoin
# [bitcoin, http://dbpedia.org/resource/Bitcoin]
#
# chains
# [chains, http://dbpedia.org/resource/Chain_store]
#
# polygon paid top solana projects y00ts 3m
# [polygon, http://dbpedia.org/resource/Polygon] paid [top, http://dbpedia.org/resource/Jimmy_Wales] solana [projects, http://dbpedia.org/resource/Wikimedia_Foundation] y00ts , http://dbpedia.org/resource/3M]
#
# hong kong brokers
# [hong kong, http://dbpedia.org/resource/Hong_Kong] brokers [brokers, http://dbpedia.org/resource/Broker]
#
# virtual asset trading law
# [virtual, http://dbpedia.org/resource/Virtual_channel] [asset, http://dbpedia.org/resource/Asset] trading [law, http://dbpedia.org/resource/Law]

# %%
ent_map
# Out:
# {0: {'text': 'bitcoin atms',
#   'wn_mask': [0, 'standard_atmosphere'],
#   'ner_mask': [0, 0],
#   'NEL_text': '[bitcoin atms, http://dbpedia.org/resource/Bitcoin_ATM]'},
#  1: {'text': 'crypto law',
#   'wn_mask': [0, 'law'],
#   'ner_mask': [0, 0],
#   'NEL_text': '[crypto, http://dbpedia.org/resource/Cryptography] [law, http://dbpedia.org/resource/Law]'},
#  2: {'text': 'lee jung hoon',
#   'wn_mask': ['lee', 'Jung', 0],
#   'ner_mask': [0, 0, 0],
#   'NEL_text': '[lee jung, http://dbpedia.org/resource/Lee_Jung] [jung hoon, http://dbpedia.org/resource/Jung_Hoon]'},
#  3: {'text': 'ripple ceo brad garlinghouse',
#   'wn_mask': ['ripple', 'chief_executive_officer', 'brad', 0],
#   'ner_mask': [0, 0, 0, 0],
#   'NEL_text': '[ripple, http://dbpedia.org/resource/Ripple_marks] [ceo, http://dbpedia.org/resource/Chief_executive_officer] [brad garlinghouse, http://dbpedia.org/resource/Brad_Garlinghouse]'},
#  4: {'text': 'alleged grift',
#   'wn_mask': ['alleged', 0],
#   'ner_mask': [0, 0],
#   'NEL_text': '[alleged, http://dbpedia.org/resource/Allegation] [grift, http://dbpedia.org/resource/Confidence_trick]'},
#  5: {'text': 'their role', 'wn_mask': [0, 'role'], 'ner_mask': [0, 0]},
#  6: {'text': 'bahamas liquidators',
#   'wn_mask': ['Bahamas', 'murderer'],
#   'ner_mask': [0, 0],
#   'NEL_text': '[bahamas, http://dbpedia.org/resource/The_Bahamas] [liquidators, http://dbpedia.org/resource/Liquidation]'},
#  7: {'text': 'track stolen user cash',
#   'wn_mask': ['track', 'steal', 'user', 'cash'],
#   'ner_mask': [0, 0, 0, 0],
#   'NEL_text': '[track, http://dbpedia.org/resource/Track_and_field] [stolen, http://dbpedia.org/resource/Stolen_base] [user, http://dbpedia.org/resource/Wikipedia] [cash, http://dbpedia.org/resource/Cash]'},
#  8: {'text': 'lightning network',
#   'wn_mask': ['lightning', 'network'],
#   'ner_mask': [0, 0],
#   'NEL_text': '[lightning, http://dbpedia.org/resource/Lightning] [network, http://dbpedia.org/resource/Computer_network]'},
#  9: {'text': 'car',
#   'wn_mask': ['car'],
#   'ner_mask': [0],
#   'NEL_text': '[car, http://dbpedia.org/resource/Car]'},
#  10: {'text': 'after us jobs report',
#   'wn_mask': ['subsequently', 'uranium', 'speculate', 'reputation'],
#   'ner_mask': [0, 0, 0, 0],
#   'NEL_text': 'after us [jobs, http://dbpedia.org/resource/Employment] report'},
#  11: {'text': '17k as interest rates plunge',
#   'wn_mask': [0, 'deoxyadenosine_monophosphate', 'sake', 'rates', 'plunge'],
#   'ner_mask': [('17', 'CARDINAL'), 0, 0, 0, 0],
#   'NEL_text': '17k as [interest rates, http://dbpedia.org/resource/Interest_rate] plunge [plunge, http://dbpedia.org/resource/Waterfall]'},
#  12: {'text': 'us feds',
#   'wn_mask': ['uranium', 'Federal_Reserve_System'],
#   'ner_mask': [0, 0],
#   'NEL_text': 'us [feds, http://dbpedia.org/resource/Feds]'},
#  13: {'text': 'cautious optimism',
#   'wn_mask': ['timid', 'optimism'],
#   'ner_mask': [0, 0],
#   'NEL_text': 'cautious [optimism, http://dbpedia.org/resource/Optimism]'},
#  14: {'text': 'crypto conglomerate dcg',
#   'wn_mask': [0, 'pudding_stone', 0],
#   'ner_mask': [0, 0, 0],
#   'NEL_text': '[crypto, http://dbpedia.org/resource/Cryptography] [conglomerate, http://dbpedia.org/resource/Conglomerate_(geology)] dcg'},
#  15: {'text': 'stablecoins', 'wn_mask': [0], 'ner_mask': [0]},
#  16: {'text': 'new tokens',
#   'wn_mask': ['raw', 'token'],
#   'ner_mask': [0, 0],
#   'NEL_text': 'new [tokens, http://dbpedia.org/resource/Token_coin]'},
#  17: {'text': 'nft collective proof signs',
#   'wn_mask': [0, 'corporate', 'validation', 'signboard'],
#   'ner_mask': [0, 0, 0, 0],
#   'NEL_text': 'nft [collective, http://dbpedia.org/resource/Collective] [proof, http://dbpedia.org/resource/Mathematical_proof] [signs, http://dbpedia.org/resource/Medical_sign]'},
#  18: {'text': 'doj',
#   'wn_mask': ['Department_of_Justice'],
#   'ner_mask': [0],
#   'NEL_text': '[doj, http://dbpedia.org/resource/United_States_Department_of_Justice]'},
#  19: {'text': 'ftx', 'wn_mask': [0], 'ner_mask': [0]},
#  20: {'text': 'audi backed startup holoride',
#   'wn_mask': [0, 'bet_on', 'inauguration', 0],
#   'ner_mask': [0, 0, 0, 0],
#   'NEL_text': '[audi, http://dbpedia.org/resource/Audi] [backed, http://dbpedia.org/resource/A-side_and_B-side] [startup, http://dbpedia.org/resource/Startup_company] holoride'},
#  21: {'text': 'zero hash',
#   'wn_mask': ['zero', 'hashish'],
#   'ner_mask': [('zero', 'CARDINAL'), 0],
#   'NEL_text': 'zero [hash, http://dbpedia.org/resource/Hash_function]'},
#  22: {'text': 'equities',
#   'wn_mask': ['fairness'],
#   'ner_mask': [0],
#   'NEL_text': '[equities, http://dbpedia.org/resource/Stock]'},
#  23: {'text': 'congress may restrict stock trading',
#   'wn_mask': ['sexual_intercourse',
#    'whitethorn',
#    'restrict',
#    'store',
#    'trade'],
#   'ner_mask': [0, 0, 0, 0, 0],
#   'NEL_text': '[congress, http://dbpedia.org/resource/United_States_Congress] may [restrict, http://dbpedia.org/resource/Restrict] [stock trading, http://dbpedia.org/resource/Stock_trader]'},
#  24: {'text': 'growth', 'wn_mask': ['increase'], 'ner_mask': [0]},
#  25: {'text': 'morocco',
#   'wn_mask': ['morocco'],
#   'ner_mask': [0],
#   'NEL_text': '[morocco, http://dbpedia.org/resource/Morocco_leather]'},
#  26: {'text': 'first instance',
#   'wn_mask': ['first_gear', 'example'],
#   'ner_mask': [('first', 'ORDINAL'), 0],
#   'NEL_text': 'first [instance, http://dbpedia.org/resource/Instance_variable]'},
#  27: {'text': 'crypto bank juno',
#   'wn_mask': [0, 'savings_bank', 'Juno'],
#   'ner_mask': [0, 0, 0],
#   'NEL_text': '[crypto, http://dbpedia.org/resource/Cryptocurrency] bank [juno, http://dbpedia.org/resource/Juno_Award]'},
#  28: {'text': 'next session',
#   'wn_mask': ['next', 'session'],
#   'ner_mask': [0, 0]},
#  29: {'text': 'united talent agency',
#   'wn_mask': ['united', 'talent', 'means'],
#   'ner_mask': [0, 0, 0],
#   'NEL_text': '[united talent agency, http://dbpedia.org/resource/United_Talent_Agency]'},
#  30: {'text': 'definition',
#   'wn_mask': ['definition'],
#   'ner_mask': [0],
#   'NEL_text': '[definition, http://dbpedia.org/resource/Definition]'},
#  31: {'text': '2022', 'wn_mask': [0], 'ner_mask': [0]},
#  32: {'text': 'bitcoin',
#   'wn_mask': [0],
#   'ner_mask': [0],
#   'NEL_text': '[bitcoin, http://dbpedia.org/resource/Bitcoin]'},
#  33: {'text': 'chains',
#   'wn_mask': ['range'],
#   'ner_mask': [0],
#   'NEL_text': '[chains, http://dbpedia.org/resource/Chain_store]'},
#  34: {'text': 'polygon paid top solana projects y00ts 3m',
#   'wn_mask': ['polygon', 'pay_up', 'top', 0, 'project', 0, 0],
#   'ner_mask': [('3m', 'QUANTITY'), 0, 0, 0, 0, 0, 0],
#   'NEL_text': '[polygon, http://dbpedia.org/resource/Polygon] paid [top, http://dbpedia.org/resource/Jimmy_Wales] solana [projects, http://dbpedia.org/resource/Wikimedia_Foundation] y00ts , http://dbpedia.org/resource/3M]'},
#  35: {'text': 'hong kong brokers',
#   'wn_mask': [0, 0, 'broker'],
#   'ner_mask': [0, 0, 0],
#   'NEL_text': '[hong kong, http://dbpedia.org/resource/Hong_Kong] brokers [brokers, http://dbpedia.org/resource/Broker]'},
#  36: {'text': 'virtual asset trading law',
#   'wn_mask': ['virtual', 'asset', 'trade', 'law'],
#   'NEL_text': '[virtual, http://dbpedia.org/resource/Virtual_channel] [asset, http://dbpedia.org/resource/Asset] trading [law, http://dbpedia.org/resource/Law]'}}

# %%
# import sparql
# import ssl
#
# # INIT SSL
# if hasattr(ssl, '_create_unverified_context'):
#     ssl._create_default_https_context = ssl._create_unverified_context
#
# #entityTypes = ['PERSON','NORP', 'FAC', 'ORG', 'GPE', 'LOC', 'PRODUCT', 'EVENT', 'WORK_OF_ART', 'LAW']
# #[tok, tok, tok]
#
# def wikification(entities):
#     s = sparql.Service("http://dbpedia.org/sparql", "GET")
#
#     found_num = 0
#     wikified = [0] * len(entities)
#
#     for _ in range(0, len(entities)):
#         entity = entities[_]
#
#         if entity != 0:
#             searchText = entities[_].replace('"', '')
#             curQuery = 'SELECT DISTINCT * WHERE '
#             curQuery = curQuery + '{ ?url rdfs:label "' + searchText + '"@en . '
#             curQuery = curQuery + 'FILTER(STRSTARTS(str(?url), "http://dbpedia.org/resource/"))}'
#             results = s.query(curQuery).fetchall()
#
#             if len(results) > 0:
#                 found_num = found_num + 1
#                 for result in results:
#                     resourceName = sparql.unpack_row(result)[0]
#
#                     if 'Category:' not in resourceName and 'property' not in resourceName:
#                         print(resourceName)
#                         wikified[_] = resourceName
#
#             return wikified

# %%
# # Entity Link
#
# for _ in range(0, len(ent_map) - 1):
#     ner_mask = ent_map[_]["ner_mask"]
#     wn_mask = ent_map[_]["wn_mask"]
#
#     combined_ents = [0] * len(ner_mask)
#     for i, (ner_mask, wn_tok) in enumerate(zip(ner_mask, wn_mask)):
#         if type(ner_mask) == tuple:
#             ner_tok, type_ = ner_mask
#
#         else: ner_tok = 0
#
#         if ner_tok == 0 and wn_tok == 0:
#             combined_ents[i] = 0
#
#         elif ner_tok != 0 and wn_tok == 0:
#             combined_ents[i] = str(ner_tok)
#
#         else:
#             combined_ents[i] = str(wn_tok)
#
#
#     ent_map[_]["wiki_link"] = wikification(combined_ents)
# Out:
# http://dbpedia.org/resource/Bahamas
# http://dbpedia.org/resource/17

# %%
# import spacy
# nlp = spacy.load("en_core_web_sm")
#
# def noun_chunks(text):
#     doc = nlp(text)
#
#     chunks = []
#     for chunk in doc.noun_chunks:
#         chunks.append(chunk.text)
#
#     return " ".join(_ for _ in chunks)
#
# for k, v in ent_map.items():
#     ent_map[k]["noun_chunks"].append(noun_chunks(v["text"]))
#
# pprint(ent_map)
# Out:
# {0: {'noun_chunks': ['bitcoin atms'],
#      'text': 'bitcoin atms',
#      'wn_mask': [0, 0]},
#  1: {'noun_chunks': ['crypto law'], 'text': 'crypto law', 'wn_mask': [0, 0]},
#  2: {'noun_chunks': ['lee jung hoon'],
#      'text': 'lee jung hoon',
#      'wn_mask': [0, 0, 0]},
#  3: {'noun_chunks': ['ripple ceo brad garlinghouse'],
#      'text': 'ripple ceo brad garlinghouse',
#      'wn_mask': [0, 0, 0, 0]},
#  4: {'noun_chunks': ['alleged grift'],
#      'text': 'alleged grift',
#      'wn_mask': [0, 0]},
#  5: {'noun_chunks': ['their role'], 'text': 'their role', 'wn_mask': [0, 0]},
#  6: {'noun_chunks': ['bahamas liquidators'],
#      'text': 'bahamas liquidators',
#      'wn_mask': [0, 0]},
#  7: {'noun_chunks': ['stolen user cash'],
#      'text': 'track stolen user cash',
#      'wn_mask': [0, 0, 0, 0]},
#  8: {'noun_chunks': ['lightning network'],
#      'text': 'lightning network',
#      'wn_mask': [0, 0]},
#  9: {'noun_chunks': ['car'], 'text': 'car', 'wn_mask': [0]},
#  10: {'noun_chunks': ['us jobs'],
#       'text': 'after us jobs report',
#       'wn_mask': [0, 0, 0, 0]},
#  11: {'noun_chunks': ['17k interest rates'],
#       'text': '17k as interest rates plunge',
#       'wn_mask': [0, 0, 0, 0, 0]},
#  12: {'noun_chunks': ['us'], 'text': 'us feds', 'wn_mask': [0, 0]},
#  13: {'noun_chunks': ['cautious optimism'],
#       'text': 'cautious optimism',
#       'wn_mask': [0, 0]},
#  14: {'noun_chunks': ['crypto conglomerate'],
#       'text': 'crypto conglomerate dcg',
#       'wn_mask': [0, 0, 0]},
#  15: {'noun_chunks': ['stablecoins'], 'text': 'stablecoins', 'wn_mask': [0]},
#  16: {'noun_chunks': ['new tokens'], 'text': 'new tokens', 'wn_mask': [0, 0]},
#  17: {'noun_chunks': ['nft collective proof signs'],
#       'text': 'nft collective proof signs',
#       'wn_mask': [0, 0, 0, 0]},
#  18: {'noun_chunks': ['doj'], 'text': 'doj', 'wn_mask': [0]},
#  19: {'noun_chunks': ['ftx'], 'text': 'ftx', 'wn_mask': [0]},
#  20: {'noun_chunks': ['audi holoride'],
#       'text': 'audi backed startup holoride',
#       'wn_mask': [0, 0, 0, 0]},
#  21: {'noun_chunks': ['zero hash'], 'text': 'zero hash', 'wn_mask': [0, 0]},
#  22: {'noun_chunks': ['equities'], 'text': 'equities', 'wn_mask': [0]},
#  23: {'noun_chunks': ['congress stock trading'],
#       'text': 'congress may restrict stock trading',
#       'wn_mask': [0, 0, 0, 0, 0]},
#  24: {'noun_chunks': ['growth'], 'text': 'growth', 'wn_mask': [0]},
#  25: {'noun_chunks': ['morocco'], 'text': 'morocco', 'wn_mask': [0]},
#  26: {'noun_chunks': ['first instance'],
#       'text': 'first instance',
#       'wn_mask': [0, 0]},
#  27: {'noun_chunks': ['crypto bank juno'],
#       'text': 'crypto bank juno',
#       'wn_mask': [0, 0, 0]},
#  28: {'noun_chunks': ['next session'],
#       'text': 'next session',
#       'wn_mask': [0, 0]},
#  29: {'noun_chunks': ['united talent agency'],
#       'text': 'united talent agency',
#       'wn_mask': [0, 0, 0]},
#  30: {'noun_chunks': ['definition'], 'text': 'definition', 'wn_mask': [0]},
#  31: {'noun_chunks': [''], 'text': '2022', 'wn_mask': [0]},
#  32: {'noun_chunks': [''], 'text': 'bitcoin', 'wn_mask': [0]},
#  33: {'noun_chunks': ['chains'], 'text': 'chains', 'wn_mask': [0]},
#  34: {'noun_chunks': ['polygon y00ts'],
#       'text': 'polygon paid top solana projects y00ts 3m',
#       'wn_mask': [0, 0, 0, 0, 0, 0, 0]},
#  35: {'noun_chunks': ['hong kong brokers'],
#       'text': 'hong kong brokers',
#       'wn_mask': [0, 0, 0]},
#  36: {'noun_chunks': ['virtual asset trading law'],
#       'text': 'virtual asset trading law',
#       'wn_mask': [0, 0, 0, 0]}}

# %%
# sample = random.randint(1, len(ent_map))
#
# sent = ent_map[sample]["text"].split()
# ent_map["ner_mask"] = [0] * len(sent)
# doc = nlp(ent_map[sample]["text"])
#
# ents = []
# for sent in doc.sentences:
#     for ent in sent.ents:
#         ents.append(ent.text, ent.type)

# %%
# TODO: More Noun Patterns
# # Noun Phrase Chunking
# import nltk
# from nltk.chunk import RegexpParser
# from nltk import word_tokenize, pos_tag
#
# def reg_chunker(sent, expression = r'NP: {<NN.?>+<NN.?>}'):
#     sent = pos_tag(word_tokenize(sent))
#     cp = nltk.RegexpParser(expression)
#     chunked = cp.parse(sent)
#
#     chunks = []
#     for chunk in chunked.subtrees(filter=lambda t: t.label() == "NP"):
#         chunks.append(str(chunk))
#
#     return " ".join(_ for _ in chunks)

# %%
# # Word Sense Dismbiguation
# from nltk.wsd import lesk
#
# sample = ent_map[0]
# sent = sample["text"]
#
# def word_sense(sent):
#     doc = nlp(sent)
#
#     sysnets = []
#     for chunk in doc.noun_chunks:
#         res = lesk(sent, chunk.text)
#
#     return " ".join(_ for _ in sysnets)
#
# word_sense(sent)
